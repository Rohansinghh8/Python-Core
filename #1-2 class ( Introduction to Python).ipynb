# %%
"RohanSingh"
# Out:
# 'RohanSingh'

# %% [markdown]
# # python class

# %% [markdown]
# ![120570.jpg](attachment:120570.jpg)

# %% [markdown]
# - rohan

# %% [markdown]
# - rohan singh
#  - 88823

# %%
ord("R")
# Out:
# 82

# %%
8-3*2-(1+1)
# Out:
# 0

# %%
42+33+29+31
# Out:
# 135

# %%
135/4
# Out:
# 33.75

# %%
A=42
B=33
C=29
D=31
A+B+C+D/4
# Out:
# 111.75

# %%
(A+B+C+D)//4
# Out:
# 33

# %%
(A+B+C+D)%4
# Out:
# 3

# %%
W=72
H=1.778
BMI=W/H**2
BMI
# Out:
# 22.775555755193142

# %%
r=10
p=3.14
VOL=4/3*p*r**3
VOL
# Out:
# 4186.666666666667

# %%
a=10
a
# Out:
# 10

# %%
a=10.0
int(a)
# Out:
# 10

# %%
a=10
a=str(a)
a
# Out:
# '10'

# %%
a=int(a)
a
# Out:
# 10

# %%
a=10
a=float(a)
a
# Out:
# 10.0

# %%
a=str(a)
a
# Out:
# '10.0'

# %%
int(a)
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8292/991674727.py in <module>
# ----> 1 int(a)
#       2 a
#
# ValueError: invalid literal for int() with base 10: '10.0'

# %%
v=23.456
v=int(v)
v
# Out:
# 23

# %%
v=str(v)
v
# Out:
# '23.0'

# %%
v=float(v)
v
# Out:
# 23.0

# %%
v=int(v)
v
# Out:
# 23

# %%
v=str(v)
v
# Out:
# '23'

# %%
v=float(v)
v
# Out:
# 23.0

# %%
v=float(str(int(float(str(int(v))))))

# %%
v
# Out:
# 23.0

# %%
s="12345.098765"
s=str(float(str(float(int(str(int(float(s))))))))
s
# Out:
# '12345.0'

# %%
import keyword
r= keyword.kwlist
r
# Out:
# ['False',
#  'None',
#  'True',
#  '__peg_parser__',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
# Hi everyone, my my is rohan singh
"""A madrid software
saturday now we are donig puthone code
with my friend aman duggal"""
# Out:
# 'A madrid software\nsaturday now we are donig puthone code\nwith my friend aman duggal'

# %%
print("rohan",end="\n")
# Out:
# rohan

# %%
a= input()
a
# Out:
# 25
# '25'

# %%
int(a)
# Out:
# 25

# %%
a=float(input())
# Out:
# 52.02

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27528/670150075.py in <module>
# ----> 1 int(a)
#
# NameError: name 'a' is not defined

# %%
'''31st JULY Python Class'''
n=19
float(str(int(float(str(float(n))))))
# Out:
# 19.0

# %%
#COMPARISION OPERATION
#always shows value in boolean
A=10
B=30
A>B
# Out:
# False

# %%
A>=B
# Out:
# False

# %%
#logical operations
'''AND,OR,NOT'''
a=100
b=200
c=50
a>b and a<c
# Out:
# False

# %%
a>=b and a!=c
# Out:
# False

# %%
a=10
b=5
c=-10 
(a<=c and a>b)or(a!=c or a>=b)and(a==b and c<=b)
# Out:
# False

# %%
#assignment opreration

# %%
#identity operation
"a"in 'aman'
1 in [1,2,3,4]
"s" not in "rohan"
# Out:
# True
